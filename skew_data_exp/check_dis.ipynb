# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.random.zipf(1.5, 100)
plt.hist(data)
# Out:
# (array([99.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([1.0000000e+00, 1.4398010e+05, 2.8795920e+05, 4.3193830e+05,
#         5.7591740e+05, 7.1989650e+05, 8.6387560e+05, 1.0078547e+06,
#         1.1518338e+06, 1.2958129e+06, 1.4397920e+06]),
#  <BarContainer object of 10 artists>)

# %%
np.std(data)
# Out:
# 91765602746952.52

# %%
import numpy as np
data_np = np.random.zipf(a=1.5, size=100000)
plt.hist(data_np)
plt.yscale("log")
